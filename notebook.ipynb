# %%
from IPython.display import display, Math, Latex
display(Latex(r'''
            \begin{align*}
            \text{this is such a pain}
            \end{align*}
            '''
              ))
# Out:
#             \begin{align*}
#             \text{this is such a pain}
#             \end{align*}

# %%
<<<<<<< local
print("hello from your mom")
=======
print("hello from notebook")
>>>>>>> remote
# Out:
# hello from your mom
